# %%
import pandas as pd
import glob
import os
import urllib.request
import os.path
import numpy as np
import html5lib

# %%
os.chdir(r'C:\Users\ahmad\OneDrive\Desktop\New folder (3)\Project1\data')

# %%
all_files = glob.glob('*.txt')  
len(all_files)
# Out:
# 6863

# %%
ww=open('filename.txt','r')
for index in ww:
    valid=ww.read().splitlines()
print(len(valid))

# %%
#delete any invalid files
for file in all_files:
    if file not in valid:
        os.remove(file)

# %%
#DataFrame features
features=pd.DataFrame(columns=['لون السيارة','نوع الوقود','أصل السيارة','رخصة السيارة','نوع الجير','الزجاج','قوة الماتور','عداد السيارة','عدد الركاب','وسيلة الدفع','معروضة','أصحاب سابقون','إضافات','النوع','سنة الاصدار','سعر السيارة بالشيكل']) 
features
# Out:
# Empty DataFrame
# Columns: [لون السيارة, نوع الوقود, أصل السيارة, رخصة السيارة, نوع الجير, الزجاج, قوة الماتور, عداد السيارة, عدد الركاب, وسيلة الدفع, معروضة, أصحاب سابقون, إضافات, النوع, سنة الاصدار, سعر السيارة بالشيكل]
# Index: []

# %%
# list features
data=['لون السيارة','نوع الوقود','أصل السيارة','رخصة السيارة','نوع الجير','الزجاج','قوة الماتور','عداد السيارة','عدد الركاب','وسيلة الدفع','معروضة','أصحاب سابقون','إضافات','النوع','سنة الاصدار','سعر السيارة بالشيكل']
#table_features الجدول الاضافة
#features الفاضي
i=0
while i<len(all_files):
    url=all_files[i] 
##tabels in this file
    table_list=pd.io.html.read_html(url)
    table_features=table_list[4]
    table= table_list[3]
    price_list = table.iloc[0,1]
    # using List comprehension + isdigit() +split()
    price_list_2 = [int(i) for i in price_list.split() if i.isdigit()]
    price = price_list_2[0]
    
    
    
    #year
    year_model_list=table.iloc[0][0]
    year  = [int(i) for i in year_model_list.split() if i.isdigit()]
    
    #model
    model=''
    for k in year_model_list.split():
        if k == 'موديل':
            break
        model= model + ' '+ k
    
    
    #print(price)
    features.loc[i,'سعر السيارة بالشيكل']=price
    features.loc[i,'النوع']=model
    features.loc[i,'سنة الاصدار']=int(year[-1])
    

    j=0
    while j<len(table_features):
        for index in data:
            if table_features.iloc[j,0] == index:
                features.loc[i,index]=table_features.iloc[j,1]
        j=j+1
    i=i+1
    # list features
data=['لون السيارة','نوع الوقود','أصل السيارة','رخصة السيارة','نوع الجير','الزجاج','قوة الماتور','عداد السيارة','عدد الركاب','وسيلة الدفع','معروضة','أصحاب سابقون','إضافات','النوع','سنة الاصدار','سعر السيارة بالشيكل']
#table_features الجدول الاضافة
#features الفاضي
i=0
while i<len(all_files):
    url=all_files[i] 
##tabels in this file
    table_list=pd.io.html.read_html(url)
    table_features=table_list[4]
    table= table_list[3]
    price_list = table.iloc[0,1]
    # using List comprehension + isdigit() +split()
    price_list_2 = [int(i) for i in price_list.split() if i.isdigit()]
    price = price_list_2[0]
    
    
    
    #year
    year_model_list=table.iloc[0][0]
    year  = [int(i) for i in year_model_list.split() if i.isdigit()]
    
    #model
    model=''
    for k in year_model_list.split():
        if k == 'موديل':
            break
        model= model + ' '+ k
    
    
    #print(price)
    features.loc[i,'سعر السيارة بالشيكل']=price
    features.loc[i,'النوع']=model
    features.loc[i,'سنة الاصدار']=int(year[-1])
    

    j=0
    while j<len(table_features):
        for index in data:
            if table_features.iloc[j,0] == index:
                features.loc[i,index]=table_features.iloc[j,1]
        j=j+1
    i=i+1
    # list features
data=['لون السيارة','نوع الوقود','أصل السيارة','رخصة السيارة','نوع الجير','الزجاج','قوة الماتور','عداد السيارة','عدد الركاب','وسيلة الدفع','معروضة','أصحاب سابقون','إضافات','النوع','سنة الاصدار','سعر السيارة بالشيكل']
#table_features الجدول الاضافة
#features الفاضي
i=0
while i<len(all_files):
    url=all_files[i] 
##tabels in this file
    table_list=pd.io.html.read_html(url)
    table_features=table_list[4]
    table= table_list[3]
    price_list = table.iloc[0,1]
    # using List comprehension + isdigit() +split()
    price_list_2 = [int(i) for i in price_list.split() if i.isdigit()]
    price = price_list_2[0]
    
    
    
    #year
    year_model_list=table.iloc[0][0]
    year  = [int(i) for i in year_model_list.split() if i.isdigit()]
    
    #model
    model=''
    for k in year_model_list.split():
        if k == 'موديل':
            break
        model= model + ' '+ k
    
    
    #print(price)
    features.loc[i,'سعر السيارة بالشيكل']=price
    features.loc[i,'النوع']=model
    features.loc[i,'سنة الاصدار']=int(year[-1])
    

    j=0
    while j<len(table_features):
        for index in data:
            if table_features.iloc[j,0] == index:
                features.loc[i,index]=table_features.iloc[j,1]
        j=j+1
    i=i+1

# %%
features
# Out:
#      لون السيارة نوع الوقود أصل السيارة رخصة السيارة      نوع الجير    الزجاج  \
# 0           سكني       ديزل       خصوصي     فلسطينية  نصف اوتوماتيك  الكتروني
# 1           سكني      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 2            بيج      بنزين       خصوصي     فلسطينية           عادي      يدوي
# 3            فضي      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 4           أسود       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# ...          ...        ...         ...          ...            ...       ...
# 6857      فيراني     كهرباء       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6858        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
# 6859         فضي       ديزل       خصوصي     فلسطينية           عادي  الكتروني
# 6860      بترولي       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6861        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
#
# ...

# %%
features.isna().sum()
# Out:
# لون السيارة               0
# نوع الوقود                0
# أصل السيارة               0
# رخصة السيارة              0
# نوع الجير                 0
# الزجاج                    0
# قوة الماتور               0
# عداد السيارة           1941
# عدد الركاب              777
# وسيلة الدفع               0
# معروضة                    0
# أصحاب سابقون           1650
# إضافات                  501
# النوع                     0
# سنة الاصدار               0
# سعر السيارة بالشيكل       0
# dtype: int64

# %%
features.isna().sum().sum()
# Out:
# 4869

# %%
#fill
#fill missing values by mean
features=features.fillna({'عداد السيارة':'99999'})
features=features.fillna({'عدد الركاب':'999'})
features=features.fillna({'أصحاب سابقون':'999'})
features=features.fillna({'إضافات':'999'})

# %%
features.isna().sum().sum()
# Out:
# 0

# %%
features.to_csv('valid_file.csv',index=False)

# %%
####staaart#
df=pd.read_csv('valid_file.csv')
df
# Out:
#      لون السيارة نوع الوقود أصل السيارة رخصة السيارة      نوع الجير    الزجاج  \
# 0           سكني       ديزل       خصوصي     فلسطينية  نصف اوتوماتيك  الكتروني
# 1           سكني      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 2            بيج      بنزين       خصوصي     فلسطينية           عادي      يدوي
# 3            فضي      بنزين       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 4           أسود       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# ...          ...        ...         ...          ...            ...       ...
# 6857      فيراني     كهرباء       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6858        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
# 6859         فضي       ديزل       خصوصي     فلسطينية           عادي  الكتروني
# 6860      بترولي       ديزل       خصوصي     فلسطينية      اوتوماتيك  الكتروني
# 6861        أبيض       ديزل       عمومي     فلسطينية           عادي  الكتروني
#
# ...

# %%
# drop columns 
df.drop('لون السيارة', inplace=True, axis=1)
df.drop('الزجاج', inplace=True, axis=1)
df.drop('معروضة', inplace=True, axis=1)

# %%
df['قوة الماتور'] = df['قوة الماتور'].astype(int)

# %%
df
# Out:
#      نوع الوقود أصل السيارة رخصة السيارة      نوع الجير  قوة الماتور  \
# 0          ديزل       خصوصي     فلسطينية  نصف اوتوماتيك         2500
# 1         بنزين       خصوصي     فلسطينية      اوتوماتيك         1600
# 2         بنزين       خصوصي     فلسطينية           عادي          906
# 3         بنزين       خصوصي     فلسطينية      اوتوماتيك         1200
# 4          ديزل       خصوصي     فلسطينية      اوتوماتيك         2000
# ...         ...         ...          ...            ...          ...
# 6857     كهرباء       خصوصي     فلسطينية      اوتوماتيك         1000
# 6858       ديزل       عمومي     فلسطينية           عادي         2400
# 6859       ديزل       خصوصي     فلسطينية           عادي         1600
# 6860       ديزل       خصوصي     فلسطينية      اوتوماتيك         2200
# 6861       ديزل       عمومي     فلسطينية           عادي         2500
#
#      عداد السيارة عدد الركاب      وسيلة الدفع أصحاب سابقون  \
# 0          130000        7+1  إمكانية التقسيط            2
# ...

# %%
print(df["نوع الوقود"].unique())
print(df["أصل السيارة"].unique())
print(df["رخصة السيارة"].unique())
print(df["وسيلة الدفع"].unique())
print(df["سنة الاصدار"].unique())
#print(df["سعر السيارة بالشيكل"].unique())
#print(df["النوع"].unique())
# Out:
# ['ديزل' 'بنزين' 'هايبرد' 'كهرباء']
# ['خصوصي' 'عمومي' 'تأجير' 'تجاري' 'تدريب سياقة' 'حكومي']
# ['فلسطينية' 'نمرة صفراء']
# ['إمكانية التقسيط' 'نقدا فقط']
# [2007 2006 1982 2014 2015 2003 2005 2012 2016 1998 2011 1997 1967 2008
#  1999 2010 1996 1983 2000 2013 2001 1986 1984 2004 2002 2009 1994 1988
#  1993 1978 1995 1974 1989 1992 1987 1975 1985 1980 1990 1991 2017 1970
#  1981 2018 1979 1973 2019 1977 2020 1976 1968 2021 1972 2022]

# %%
#print(df["عداد السيارة"].unique())

#length = len(df["عداد السيارة"].unique())

#import numpy as np

#listA = df["عداد السيارة"].unique()

#splits = np.array_split(listA, 3)

#for array in splits:
 #   print(list(array)) 
# shGl  150 lf    _   -  80 lf  lzyd@  120 lf  47 lf   60lf   90000 kylw    000 kylw mtr    140 lf kylw mtr    16000 km 
# ................   80lf    ................   ********  75000kylw mtr   180 kylwmtr    5400 kylw   18km    105000kylw mtr
# 60 lf kylw mtr   80000 Km   27lf kylw   78 lf   143 lf

# lf kylw', '230 lf kylw mtr', 'm ntbht', '52', '50000 kylw', '13500', '230000 kylw mtr', '31000', '777', '68515', '0000014',

# %%
df['إضافات'] = df['إضافات'].astype(str)
i=0
while i<len(df):
    string=df.loc[i,'إضافات']
    search = string.find("فتحة")
    search_2 =string.find("999")
    if search != -1:
        df.loc[i,'إضافات']='1'
    if search_2 != -1:
        df.loc[i,'إضافات']='999'
    elif search == -1& search_2 == -1:
        df.loc[i,'إضافات']='0'
    i = i+1

# %%
df
# Out:
#      نوع الوقود أصل السيارة رخصة السيارة      نوع الجير  قوة الماتور  \
# 0          ديزل       خصوصي     فلسطينية  نصف اوتوماتيك         2500
# 1         بنزين       خصوصي     فلسطينية      اوتوماتيك         1600
# 2         بنزين       خصوصي     فلسطينية           عادي          906
# 3         بنزين       خصوصي     فلسطينية      اوتوماتيك         1200
# 4          ديزل       خصوصي     فلسطينية      اوتوماتيك         2000
# ...         ...         ...          ...            ...          ...
# 6857     كهرباء       خصوصي     فلسطينية      اوتوماتيك         1000
# 6858       ديزل       عمومي     فلسطينية           عادي         2400
# 6859       ديزل       خصوصي     فلسطينية           عادي         1600
# 6860       ديزل       خصوصي     فلسطينية      اوتوماتيك         2200
# 6861       ديزل       عمومي     فلسطينية           عادي         2500
#
#      عداد السيارة عدد الركاب      وسيلة الدفع أصحاب سابقون إضافات  \
# 0          130000        7+1  إمكانية التقسيط            2      1
# ...

# %%
import re

#Check if the string starts with "The" and ends with "Spain":
i=0
while i<len(df):
    count = 0
    txt=df.loc[i,'أصحاب سابقون']
    word  = re.search("صفر", txt)
    word_2 = re.search("أولى", txt)
    word_3 = re.search("ثانية", txt)
    word_4 = re.search("ثالثة", txt)
    word_5 = re.search("رابعه", txt)
    word_6 = re.search("اربعة", txt)
    word_7 = re.search("خامسة", txt)
    word_8 = re.search("عاشره", txt)
    word_9 = re.search("تاسعة", txt)
    word_10 = re.search("ثمانيه", txt)
    word_11 = re.search("سابعه", txt)
    word_12 = re.search("خمس", txt)
    word_13 = re.search("ثاني", txt)
    word_14 = re.search("ثانية", txt)
    word_15 = re.search("ثالثه", txt)
    word_16 = re.search("1", txt)
    word_17 = re.search("2", txt)
    word_18 = re.search("3", txt)
    word_19 = re.search("4", txt)
    word_20 = re.search("5", txt)
    word_21 = re.search("6", txt)
    word_22 = re.search("7", txt)
    word_23 = re.search("٩", txt)  
    word_24 = re.search("٢", txt) 
    word_25 = re.search("٥", txt)
    word_26 = re.search("٣", txt) 
    word_27 = re.search("٦", txt) 
    word_28 = re.search("٤", txt)
    
    word_29 = re.search("00", txt)
    word_30 = re.search("٨", txt)
    word_31 = re.search("٢", txt)
    word_32 = re.search("٤", txt)
    word_33 = re.search("١", txt)
    word_34 = re.search("خامساً", txt)  
    word_35 = re.search("تالته", txt) 
    word_36 = re.search("اولىً", txt)
    word_37 = re.search("اولى", txt) 
    word_38 = re.search("تانية", txt) 
    word_39 = re.search("ثالث", txt)
    word_40 = re.search("اول", txt) 
    word_41 = re.search("اولي", txt) 
    word_42 = re.search("رابعة", txt)
    
    
    word_43 = re.search("Zero", txt)
    word_44 = re.search("خامسه", txt)
    word_45 = re.search("أولي", txt)
    word_46 = re.search("خامسه", txt)
    word_47 = re.search("اربعه", txt)  
    word_48 = re.search("أولئ", txt) 
    word_49 = re.search("ثاتيه", txt)
 
    word_43 = re.search("Zero", txt)
    word_44 = re.search("خامسه", txt)
    word_45 = re.search("أولي", txt)
    word_46 = re.search("خامسه", txt)
    word_47 = re.search("اربعه", txt)  
    word_48 = re.search("أولئ", txt) 
    word_49 = re.search("ثاتيه", txt)
    word_50 = re.search("تانيه", txt)
    word_51 = re.search("واحد", txt)  
    word_52 = re.search("تاني", txt) 
    word_53 = re.search("سادسة", txt)
    word_54 = re.search("واحدة", txt)
    
    if word:
        df.loc[i,'أصحاب سابقون'] = '999'  
    elif word_2:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_3:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_4:
        df.loc[i,'أصحاب سابقون'] = '3'
    elif word_5:
        df.loc[i,'أصحاب سابقون'] = '4'
    elif word_6:
        df.loc[i,'أصحاب سابقون'] = '4'
    elif word_7:
        df.loc[i,'أصحاب سابقون'] = '5'
    elif word_8:
        df.loc[i,'أصحاب سابقون'] = '10'
    elif word_9:
        df.loc[i,'أصحاب سابقون'] = '9'
    elif word_10:
        df.loc[i,'أصحاب سابقون'] = '8'
    elif word_11:
        df.loc[i,'أصحاب سابقون'] = '7'
    elif word_12:
        df.loc[i,'أصحاب سابقون'] = '5'
    elif word_13:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_14:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_15:
        df.loc[i,'أصحاب سابقون'] = '3' 
    elif word_16:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_17:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_18:
        df.loc[i,'أصحاب سابقون'] = '3'
    elif word_19:
        df.loc[i,'أصحاب سابقون'] = '4'
    elif word_20:
        df.loc[i,'أصحاب سابقون'] = '5'
    elif word_21:
        df.loc[i,'أصحاب سابقون'] = '6'
    elif word_22:
        df.loc[i,'أصحاب سابقون'] = '7'
    elif word_23:
        df.loc[i,'أصحاب سابقون'] = '9'
    elif word_24:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_25:
        df.loc[i,'أصحاب سابقون'] = '5'
    elif word_26:
        df.loc[i,'أصحاب سابقون'] = '3'
    elif word_27:
        df.loc[i,'أصحاب سابقون'] = '6'
    elif word_28:
        df.loc[i,'أصحاب سابقون'] = '4'
   
    elif word_29:
        df.loc[i,'أصحاب سابقون'] = '999'
    elif word_30:
        df.loc[i,'أصحاب سابقون'] = '8'
    elif word_31:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_32:
        df.loc[i,'أصحاب سابقون'] = '4'
    elif word_33:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_34:
        df.loc[i,'أصحاب سابقون'] = '5'
    elif word_35:
        df.loc[i,'أصحاب سابقون'] = '3'
    elif word_36:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_37:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_38:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_39:
        df.loc[i,'أصحاب سابقون'] = '3'
    elif word_40:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_41:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_42:
        df.loc[i,'أصحاب سابقون'] = '4'
    elif word_43:
        df.loc[i,'أصحاب سابقون'] = '0'
    elif word_44:
        df.loc[i,'أصحاب سابقون'] = '5'
    elif word_45:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_46:
        df.loc[i,'أصحاب سابقون'] = '5'
    elif word_47:
        df.loc[i,'أصحاب سابقون'] = '4'
    elif word_48:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_49:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_50:
        df.loc[i,'أصحاب سابقون'] = '2'
    
    elif word_51:
        df.loc[i,'أصحاب سابقون'] = '1'
    elif word_52:
        df.loc[i,'أصحاب سابقون'] = '2'
    elif word_53:
        df.loc[i,'أصحاب سابقون'] = '6'
    elif word_54:
        df.loc[i,'أصحاب سابقون'] = '1'
    i=i+1

# %%
df
# Out:
#      نوع الوقود أصل السيارة رخصة السيارة      نوع الجير  قوة الماتور  \
# 0          ديزل       خصوصي     فلسطينية  نصف اوتوماتيك         2500
# 1         بنزين       خصوصي     فلسطينية      اوتوماتيك         1600
# 2         بنزين       خصوصي     فلسطينية           عادي          906
# 3         بنزين       خصوصي     فلسطينية      اوتوماتيك         1200
# 4          ديزل       خصوصي     فلسطينية      اوتوماتيك         2000
# ...         ...         ...          ...            ...          ...
# 6857     كهرباء       خصوصي     فلسطينية      اوتوماتيك         1000
# 6858       ديزل       عمومي     فلسطينية           عادي         2400
# 6859       ديزل       خصوصي     فلسطينية           عادي         1600
# 6860       ديزل       خصوصي     فلسطينية      اوتوماتيك         2200
# 6861       ديزل       عمومي     فلسطينية           عادي         2500
#
#      عداد السيارة عدد الركاب      وسيلة الدفع أصحاب سابقون إضافات  \
# 0          130000        7+1  إمكانية التقسيط            2      1
# ...

# %%
i=0
while i<len(df):
    txt=df.loc[i,'عدد الركاب']
    if '1+7' in txt :
        df.loc[i,'عدد الركاب']='8'
    elif '7:1' in txt :
        df.loc[i,'عدد الركاب']='8'
    elif '7,+ 1' in txt :
        df.loc[i,'عدد الركاب']='8'
    elif '٧' in txt :
        df.loc[i,'عدد الركاب']='7'
    elif '4+١' in txt :
        df.loc[i,'عدد الركاب']='5'
    elif '6+1' in txt :
        df.loc[i,'عدد الركاب']='7'
    elif '٤+١' in txt :
        df.loc[i,'عدد الركاب']='5' 
    elif '5+1' in txt :
        df.loc[i,'عدد الركاب']='6'
    elif '4+1' in txt :
        df.loc[i,'عدد الركاب']='5'
    elif '7+1' in txt :
        df.loc[i,'عدد الركاب']='8' 
    elif 'مثال: 4 + 1' in txt :
        df.loc[i,'عدد الركاب']='5'
    
    elif '5+2' in txt :
        df.loc[i,'عدد الركاب']='7' 
    elif '٧+1' in txt :
        df.loc[i,'عدد الركاب']='8'
    elif '٥+١' in txt :
        df.loc[i,'عدد الركاب']='6'
    elif '1+1' in txt :
        df.loc[i,'عدد الركاب']='2' 
    elif '22' in txt :
        df.loc[i,'عدد الركاب']='22'
     
    elif '6±١' in txt :
        df.loc[i,'عدد الركاب']='7' 
    elif '+1' in txt :
        df.loc[i,'عدد الركاب']='1'
    elif '6+١' in txt :
        df.loc[i,'عدد الركاب']='7'
    elif '2+1' in txt :
        df.loc[i,'عدد الركاب']='3' 
    elif '١+٤' in txt :
        df.loc[i,'عدد الركاب']='5'
        
        
    elif '4+2' in txt :
        df.loc[i,'عدد الركاب']='6'
    elif '٦+١' in txt :
        df.loc[i,'عدد الركاب']='7'
    elif '2/1' in txt :
        df.loc[i,'عدد الركاب']='3'
    elif '٨+١' in txt :
        df.loc[i,'عدد الركاب']='9' 
    elif '8+1' in txt :
        df.loc[i,'عدد الركاب']='9'
    elif '6x1+٤' in txt :
        df.loc[i,'عدد الركاب']='10'
    elif '1+2' in txt :
        df.loc[i,'عدد الركاب']='3'
    elif '٧+١' in txt :
        df.loc[i,'عدد الركاب']='8'
    
    elif '7 =1' in txt :
        df.loc[i,'عدد الركاب']='8'
    elif '7.1' in txt :
        df.loc[i,'عدد الركاب']='8' 
    elif '9+1' in txt :
        df.loc[i,'عدد الركاب']='10'
    elif 'اكثر من 10' in txt :
        df.loc[i,'عدد الركاب']='10'
    elif '3+1' in txt :
        df.loc[i,'عدد الركاب']='4'
    elif '000' in txt :
        df.loc[i,'عدد الركاب']='999'
    elif '4\\١' in txt :
        df.loc[i,'عدد الركاب']='5'
    elif '1٠4' in txt :
        df.loc[i,'عدد الركاب']='5'

    elif '6x1' in txt :
        df.loc[i,'عدد الركاب']='7'
    elif '1+٤' in txt :
        df.loc[i,'عدد الركاب']='5'
    elif '8' in txt :
        df.loc[i,'عدد الركاب']='8'
    elif '2' in txt :
        df.loc[i,'عدد الركاب']='2'
    elif '1' in txt :
        df.loc[i,'عدد الركاب']='1'

    i=i+1

# %%
df
# Out:
#      نوع الوقود أصل السيارة رخصة السيارة      نوع الجير  قوة الماتور  \
# 0          ديزل       خصوصي     فلسطينية  نصف اوتوماتيك         2500
# 1         بنزين       خصوصي     فلسطينية      اوتوماتيك         1600
# 2         بنزين       خصوصي     فلسطينية           عادي          906
# 3         بنزين       خصوصي     فلسطينية      اوتوماتيك         1200
# 4          ديزل       خصوصي     فلسطينية      اوتوماتيك         2000
# ...         ...         ...          ...            ...          ...
# 6857     كهرباء       خصوصي     فلسطينية      اوتوماتيك         1000
# 6858       ديزل       عمومي     فلسطينية           عادي         2400
# 6859       ديزل       خصوصي     فلسطينية           عادي         1600
# 6860       ديزل       خصوصي     فلسطينية      اوتوماتيك         2200
# 6861       ديزل       عمومي     فلسطينية           عادي         2500
#
#      عداد السيارة عدد الركاب      وسيلة الدفع أصحاب سابقون إضافات  \
# 0          130000          8  إمكانية التقسيط            2      1
# ...

# %%
# Import label encode
from sklearn import preprocessing

# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['نوع الوقود']= label_encoder.fit_transform(df['نوع الوقود'])
df['أصل السيارة']= label_encoder.fit_transform(df['أصل السيارة'])
df['رخصة السيارة']= label_encoder.fit_transform(df['رخصة السيارة'])
df['نوع الجير']= label_encoder.fit_transform(df['نوع الجير'])
df['وسيلة الدفع']= label_encoder.fit_transform(df['وسيلة الدفع'])
df['النوع']= label_encoder.fit_transform(df['النوع'])
df['إضافات']= label_encoder.fit_transform(df['إضافات'])
df['عدد الركاب']= label_encoder.fit_transform(df['إضافات'])
df['أصحاب سابقون']= label_encoder.fit_transform(df['إضافات'])

# %%
df
# Out:
#       نوع الوقود  أصل السيارة  رخصة السيارة  نوع الجير  قوة الماتور  \
# 0              1            4             0          2         2500
# 1              0            4             0          0         1600
# 2              0            4             0          1          906
# 3              0            4             0          0         1200
# 4              1            4             0          0         2000
# ...          ...          ...           ...        ...          ...
# 6857           2            4             0          0         1000
# 6858           1            5             0          1         2400
# 6859           1            4             0          1         1600
# 6860           1            4             0          0         2200
# 6861           1            5             0          1         2500
#
#      عداد السيارة  عدد الركاب  وسيلة الدفع  أصحاب سابقون  إضافات  النوع  \
# 0          130000           1            0             1       1    429
# ...

# %%
df2 = df.copy()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
names_column=['سنة الاصدار','سعر السيارة بالشيكل','قوة الماتور',]
i=0
while(i<3):
    Q1 = df2[names_column[i]].quantile(0.25)
    Q3 = df2[names_column[i]].quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = percentile75 + 1.5 * iqr
    lower_limit = percentile25 - 1.5 * iqr
    new_df_cap[names_column[i]] = np.where(
    new_df_cap[names_column[i]] > upper_limit,
    upper_limit,
    np.where(
        new_df_cap[names_column[i]] < lower_limit,
        lower_limit,
        new_df_cap[names_column[i]]
    ))
    i=i+1

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df2['سنة الاصدار'])
plt.subplot(2,2,2)
sns.boxplot(df2['سنة الاصدار'])
plt.subplot(2,2,3)
sns.distplot(new_df_cap['سنة الاصدار'])
plt.subplot(2,2,4)
sns.boxplot(new_df_cap['سنة الاصدار'])
plt.show()
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_5972\1754992565.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['سنة الاصدار'])
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_5972\1754992565.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
min_max_scaler = preprocessing.MinMaxScaler()
def scaleColumns(df, cols_to_scale):
    for col in cols_to_scale:
        df[col] = pd.DataFrame(min_max_scaler.fit_transform(pd.DataFrame(df2[col])),columns=[col])
    return df

# %%
df2 = scaleColumns(df2,['سنة الاصدار','سعر السيارة بالشيكل','قوة الماتور',])
df2
# Out:
#       نوع الوقود  أصل السيارة  رخصة السيارة  نوع الجير  قوة الماتور  \
# 0              1            4             0          2     0.269170
# 1              0            4             0          0     0.167978
# 2              0            4             0          1     0.089948
# 3              0            4             0          0     0.123004
# 4              1            4             0          0     0.212953
# ...          ...          ...           ...        ...          ...
# 6857           2            4             0          0     0.100517
# 6858           1            5             0          1     0.257927
# 6859           1            4             0          1     0.167978
# 6860           1            4             0          0     0.235440
# 6861           1            5             0          1     0.269170
#
#      عداد السيارة  عدد الركاب  وسيلة الدفع  أصحاب سابقون  إضافات  النوع  \
# 0          130000           1            0             1       1    429
# ...

# %%
df2.to_csv('final.csv',index=False)

# %%
import re
#Check if the string starts with "The" and ends with "Spain":
i=0

while i<len(df):
    car_odomete_str=df.loc[i,'عداد السيارة']
    txt=df.loc[i,'عداد السيارة']
    #word  = re.search("الف", txt)
    word_2  = re.search("آلف", txt)
    word_3  = re.search("ألف", txt)
    word_4  = re.search("الاف", txt)
    word_5  = re.search("كيلو", txt)
    
  
    
    word_6  = re.search("234567809876", txt)
    word_7  = re.search("Km", txt)
    word_8  = re.search("واحد", txt)
    word_9  = re.search("كم", txt)
    word_10  = re.search("ما انتبهت", txt)
    word_24  = re.search("ش", txt)
    word_11 = re.search("اكثر من سيارة", txt)
    word_12  = re.search("عداد غير حقيقي", txt)
    word_13  = re.search("o", txt)
    word_14  = re.search("متور جديد", txt)
    word_15  = re.search("جديد", txt)
    word_25  = re.search("ج", txt)
    word_16  = re.search("مش كتير", txt)
    word_17  = re.search("لا", txt)
    word_18  = re.search("شغال", txt)
    word_19  = re.search("قابل لزيادة", txt)
    word_20  = re.search("صفر", txt)
    word_21  = re.search("عداد اصلي", txt)
    word_22  = re.search("فقط", txt)
    word_23  = re.search("km", txt)
    word_26  = re.search("Mil", txt)
    word_27  = re.search("_", txt)
    word_28  = re.search("234567809876", txt)
    word_29  = re.search("-", txt)


    if word:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+'000'
    elif word_2:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= (car_odomete)+'000'
    elif word_3:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+'000'
    elif word_4:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+'000'
    elif word_5:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+''  
    elif word_6:
        df.loc[i,'عداد السيارة']= '99999'
    elif word_7:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+''   
    elif word_8:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+''   
    elif word_9:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+'' 
    elif word_10:
        df.loc[i,'عداد السيارة']= '99999'
    
    elif word_11:
        df.loc[i,'عداد السيارة']= '99999'
    elif word_12:
        df.loc[i,'عداد السيارة']= '99999'
    elif word_13:
        df.loc[i,'عداد السيارة']= '99999'    
    elif word_25:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+''
    elif word_14:
        df.loc[i,'عداد السيارة']= '99999'    
    elif word_15:
        df.loc[i,'عداد السيارة']= '99999'
    elif word_16:
        df.loc[i,'عداد السيارة']= '99999'
    elif word_17:
        df.loc[i,'عداد السيارة']= '99999' 
    elif word_18:
        df.loc[i,'عداد السيارة']= '99999'
    elif word_24:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+'' 
    elif word_19:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+''     
    elif word_20:
        df.loc[i,'عداد السيارة']= '0'
    elif word_21:
        df.loc[i,'عداد السيارة']= '99999'
    elif word_22:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+''    
    elif word_23:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+''
    elif word_26:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+'' 
    elif word_27:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+' ' 
    elif word_28:
        df.loc[i,'عداد السيارة']= '99999'
    elif word_29:
        car_odomete =[int(i)for i in car_odomete_str.split() if i.isdigit()]
        df.loc[i,'عداد السيارة']= str(car_odomete)+' ' 
    #elif word_30:
     #   car_odomete =[int(i)for i in t.split() if i.isdigit()]
      #  df.loc[i,'عداد السيارة']= '99999'  

    i=i+1
